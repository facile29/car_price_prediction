# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv("Cardetails.csv")

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# 1       250Nm@ 1500-2500rpm    5.0
# 2     12.7@ 2,700(kgm@ rpm)    5.0
# 3  22.4 kgm at 1750-2750rpm    5.0
# 4     11.5@ 4,500(kgm@ rpm)    5.0

# %%
df['name'].unique()
# Out:
# array(['Maruti Swift Dzire VDI', 'Skoda Rapid 1.5 TDI Ambition',
#        'Honda City 2017-2020 EXi', ..., 'Tata Nexon 1.5 Revotorq XT',
#        'Ford Freestyle Titanium Plus Diesel BSIV',
#        'Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
df.shape
# Out:
# (8128, 13)

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
# duplicates check 
df.duplicated().sum()
# Out:
# 1202

# %%
df.drop_duplicates(inplace= True)

# %%
df.shape
# Out:
# (6926, 13)

# %%
# check for null values 
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          208
# engine           208
# max_power        205
# torque           209
# seats            208
# dtype: int64

# %%
df.dropna(inplace= True)

# %%
df.reset_index(drop=True)
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 6712  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 6713         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 6714                  Hyundai i20 Magna  2013         320000     110000
# 6715              Hyundai Verna CRDi SX  2007         135000     119000
# 6716             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# 0     Diesel  Individual       Manual           First Owner   23.4 kmpl
# 1     Diesel  Individual       Manual          Second Owner  21.14 kmpl
# 2     Petrol  Individual       Manual           Third Owner   17.7 kmpl
# 3     Diesel  Individual       Manual           First Owner   23.0 kmpl
# 4     Petrol  Individual       Manual           First Owner   16.1 kmpl
# ...      ...         ...          ...                   ...         ...
# 6712  Petrol  Individual       Manual          Second Owner   18.9 kmpl
# 6713  Diesel  Individual       Manual          Second Owner  22.54 kmpl
# 6714  Petrol  Individual       Manual           First Owner   18.5 kmpl
# 6715  Diesel  Individual       Manual  Fourth & Above Owner   16.8 kmpl
# 6716  Diesel  Individual       Manual           First Owner   19.3 kmpl
#
#        engine   max_power                     torque  seats
# 0     1248 CC      74 bhp             190Nm@ 2000rpm    5.0
# 1     1498 CC  103.52 bhp        250Nm@ 1500-2500rpm    5.0
# 2     1497 CC      78 bhp      12.7@ 2,700(kgm@ rpm)    5.0
# 3     1396 CC      90 bhp   22.4 kgm at 1750-2750rpm    5.0
# 4     1298 CC    88.2 bhp      11.5@ 4,500(kgm@ rpm)    5.0
# ...       ...         ...                        ...    ...
# 6712   998 CC    67.1 bhp              90Nm@ 3500rpm    5.0
# 6713  1396 CC   88.73 bhp      219.7Nm@ 1500-2750rpm    5.0
# 6714  1197 CC   82.85 bhp           113.7Nm@ 4000rpm    5.0
# 6715  1493 CC     110 bhp  24@ 1,900-2,750(kgm@ rpm)    5.0
# 6716  1248 CC    73.9 bhp             190Nm@ 2000rpm    5.0
#
# [6717 rows x 13 columns]

# %%
df.shape
# Out:
# (6717, 13)

# %%
# drop unwanted columns 
df.drop(columns=['torque'], inplace=True)

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#    seats
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6717 entries, 0 to 8125
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6717 non-null   object
#  1   year           6717 non-null   int64
#  2   selling_price  6717 non-null   int64
#  3   km_driven      6717 non-null   int64
#  4   fuel           6717 non-null   object
#  5   seller_type    6717 non-null   object
#  6   transmission   6717 non-null   object
#  7   owner          6717 non-null   object
#  8   mileage        6717 non-null   object
#  9   engine         6717 non-null   object
#  10  max_power      6717 non-null   object
#  11  seats          6717 non-null   float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 682.2+ KB

# %%
# EDA

# %%
df['mileage'] = df['mileage'].str.extract(r'(\d+(\.\d+)?)')[0]

# %%
df['mileage'].unique()
# Out:
# array(['23.4', '21.14', '17.7', '23.0', '16.1', '20.14', '17.3', '23.59',
#        '20.0', '19.01', '19.3', '18.9', '18.15', '24.52', '19.7', '22.54',
#        '21.0', '25.5', '26.59', '21.5', '20.3', '21.4', '24.7', '18.2',
#        '16.8', '24.3', '14.0', '18.6', '33.44', '23.95', '17.0', '20.63',
#        '13.93', '16.0', '17.8', '18.5', '12.55', '12.99', '14.8', '13.5',
#        '26.0', '20.65', '27.3', '11.36', '17.68', '14.28', '18.53',
#        '14.84', '21.12', '20.36', '21.27', '18.16', '22.0', '25.1',
#        '20.51', '21.66', '25.2', '22.9', '16.02', '20.54', '22.77',
#        '15.71', '23.1', '19.02', '19.81', '26.2', '16.47', '15.04',
#        '19.1', '21.79', '18.8', '21.21', '15.37', '11.79', '19.0', '14.3',
#        '15.8', '15.1', '19.09', '22.32', '21.9', '14.53', '21.63',
#        '20.85', '20.45', '19.67', '23.01', '20.77', '17.92', '17.01',
#        '22.37', '19.33', '9.5', '12.83', '22.48', '16.78', '14.67',
#        '15.0', '13.96', '18.0', '12.07', '26.21', '10.8', '16.3', '13.6',
#        '14.74', '15.6', '19.56', '22.69', '19.16', '18.12', '12.1',
#        '17.5', '42.0', '20.4', '21.1', '19.44', '13.0', '21.43', '22.95',
#        '16.2', '15.3', '28.09', '17.4', '19.4', '26.6', '17.6', '28.4',
#        '14.1', '25.17', '22.74', '17.57', '16.95', '19.49', '17.21',
#        '13.2', '14.2', '26.8', '25.4', '11.5', '27.28', '17.97', '12.8',
#        '16.55', '12.05', '14.07', '21.02', '11.57', '17.9', '15.96',
#        '17.1', '17.19', '21.01', '24.0', '25.6', '21.38', '23.84',
#        '23.08', '14.24', '20.71', '15.64', '14.5', '16.34', '27.39',
#        '11.1', '13.9', '20.88', '20.92', '23.8', '24.4', '15.29', '21.19',
#        '22.5', '19.6', '23.65', '25.32', '23.5', '16.6', '23.9', '20.8',
#        '27.62', '12.9', '25.44', '17.88', '22.7', '17.2', '15.42',
#        '19.68', '18.7', '15.4', '19.34', '22.71', '25.8', '13.7', '12.2',
#        '18.49', '9.0', '0.0', '13.58', '10.1', '20.5', '25.0', '10.5',
#        '22.07', '22.3', '15.26', '20.62', '27.4', '23.2', '14.4', '18.4',
#        '30.46', '14.02', '11.0', '20.6', '22.05', '20.2', '18.1', '22.1',
#        '19.87', '13.01', '18.06', '26.1', '16.52', '13.55', '24.2',
#        '25.83', '11.2', '17.09', '21.03', '17.45', '21.64', '21.94',
#        '13.87', '19.98', '20.52', '23.57', '11.7', '17.43', '18.88',
#        '13.68', '11.18', '20.89', '11.8', '19.62', '21.7', '14.9', '19.5',
#        '10.91', '15.7', '20.73', '15.85', '20.7', '14.23', '16.5',
#        '17.36', '12.6', '16.36', '14.95', '16.9', '19.2', '16.96',
#        '22.15', '18.78', '19.61', '17.71', '18.3', '19.12', '19.72',
#        '12.0', '11.4', '23.03', '11.07', '15.9', '17.67', '20.46', '13.1',
#        '13.45', '24.8', '15.73', '15.11', '12.7', '21.2', '20.38',
#        '21.56', '13.22', '14.49', '15.05', '23.26', '15.41', '13.8',
#        '22.27', '32.52', '14.66', '12.12', '16.84', '14.09', '14.7',
#        '13.4', '15.5', '13.49', '11.88', '14.6', '10.75', '24.5', '11.74',
#        '16.07', '15.63', '26.3', '23.7', '25.47', '17.05', '23.3', '11.9',
#        '13.38', '20.86', '10.9', '18.25', '15.2', '20.37', '21.8',
#        '11.96', '24.04', '19.69', '13.73', '21.04', '25.01', '10.93',
#        '24.29', '13.44', '20.07', '19.08', '20.34', '11.68', '12.5',
#        '12.3', '23.87', '16.38', '17.42', '10.0', '18.24', '10.71',
#        '19.59', '16.7', '19.83', '21.76', '16.05', '20.28', '16.25',
#        '16.73', '18.48', '14.99', '18.76', '16.4', '19.64', '14.94',
#        '17.11', '22.8', '32.26', '33.0', '12.4', '18.44', '16.09',
#        '12.62', '21.13', '15.17', '21.73', '21.72', '12.85', '14.81',
#        '13.24', '21.49', '14.62', '26.83', '11.45', '12.08', '15.74',
#        '11.3', '14.21', '11.72', '16.51'], dtype=object)

# %%
df['engine'] = df['engine'].str.replace('CC','')

# %%
df['max_power'] = df['max_power'].str.replace('bhp','')

# %%
df.sample(5)
# Out:
#                                   name  year  selling_price  km_driven  \
# 1582                Mahindra Thar CRDe  2017         775000      35000
# 1394        Nissan Terrano XL D Option  2016         495000      56832
# 436             Nissan Micra Diesel XV  2011         254999     110000
# 2877  Volkswagen Vento Diesel Highline  2013         400000     120000
# 4061                   Tata Indigo CR4  2012         200000     230000
#
#         fuel seller_type transmission         owner mileage engine max_power  \
# 1582  Diesel  Individual       Manual   First Owner   16.55  2498       105
# 1394  Diesel      Dealer       Manual   First Owner   19.87  1461     83.14
# 436   Diesel  Individual       Manual  Second Owner   23.08  1461      63.1
# 2877  Diesel  Individual       Manual  Second Owner   20.54  1598     103.6
# 4061  Diesel  Individual       Manual   First Owner   23.57  1396        70
#
#       seats
# 1582    6.0
# 1394    5.0
# 436     5.0
# 2877    5.0
# 4061    5.0

# %%
df['mileage'] = df['mileage'].astype('float32')
df['engine'] = df['engine'].astype('int32')
df['max_power'] = df['max_power'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6717 entries, 0 to 8125
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6717 non-null   object
#  1   year           6717 non-null   int64
#  2   selling_price  6717 non-null   int64
#  3   km_driven      6717 non-null   int64
#  4   fuel           6717 non-null   object
#  5   seller_type    6717 non-null   object
#  6   transmission   6717 non-null   object
#  7   owner          6717 non-null   object
#  8   mileage        6717 non-null   float32
#  9   engine         6717 non-null   int32
#  10  max_power      6717 non-null   float32
#  11  seats          6717 non-null   float64
# dtypes: float32(2), float64(1), int32(1), int64(3), object(5)
# memory usage: 603.5+ KB

# %%
df.corr(numeric_only = True)['selling_price']
# Out:
# year             0.427335
# selling_price    1.000000
# km_driven       -0.161265
# mileage         -0.108655
# engine           0.442772
# max_power        0.692323
# seats            0.158531
# Name: selling_price, dtype: float64

# %%
# extracting brand name from name column
df['brand_name'] = df['name'].str.split(' ').str[0]

# %%
df['brand_name'].unique()
# Out:
# array(['Maruti', 'Skoda', 'Honda', 'Hyundai', 'Toyota', 'Ford', 'Renault',
#        'Mahindra', 'Tata', 'Chevrolet', 'Datsun', 'Jeep', 'Mercedes-Benz',
#        'Mitsubishi', 'Audi', 'Volkswagen', 'BMW', 'Nissan', 'Lexus',
#        'Jaguar', 'Land', 'MG', 'Volvo', 'Daewoo', 'Kia', 'Fiat', 'Force',
#        'Ambassador', 'Ashok', 'Isuzu', 'Opel'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6717 entries, 0 to 8125
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6717 non-null   object
#  1   year           6717 non-null   int64
#  2   selling_price  6717 non-null   int64
#  3   km_driven      6717 non-null   int64
#  4   fuel           6717 non-null   object
#  5   seller_type    6717 non-null   object
#  6   transmission   6717 non-null   object
#  7   owner          6717 non-null   object
#  8   mileage        6717 non-null   float32
#  9   engine         6717 non-null   int32
#  10  max_power      6717 non-null   float32
#  11  seats          6717 non-null   float64
#  12  brand_name     6717 non-null   object
# dtypes: float32(2), float64(1), int32(1), int64(3), object(6)
# memory usage: 656.0+ KB

# %%
df.drop(columns=['name'],inplace=True)

# %%
df.columns
# Out:
# Index(['year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'seats',
#        'brand_name'],
#       dtype='object')

# %%
# graphs

# %%
sns.histplot(df['selling_price'])
plt.title('Distribution of Used Car Prices')
# Out:
# Text(0.5, 1.0, 'Distribution of Used Car Prices')

# %%
df['brand_name'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='brand_name'>

# %%
sns.barplot(x=df['brand_name'],y=df['selling_price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# how many cars avaliable for each year?
df['year'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# average price per year
sns.barplot(x='year', y='selling_price', data=df, estimator='mean')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.histplot(df['km_driven'])
# Out:
# <AxesSubplot:xlabel='km_driven', ylabel='Count'>

# %%
sns.scatterplot(x='km_driven', y='selling_price', data=df, alpha=0.7)
# Out:
# <AxesSubplot:xlabel='km_driven', ylabel='selling_price'>

# %%
df['fuel'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='fuel'>

# %%
sns.barplot(x=df['fuel'],y=df['selling_price'])
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='selling_price'>

# %%
df['seller_type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='seller_type'>

# %%
sns.barplot(x=df['seller_type'],y=df['selling_price'])
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='selling_price'>

# %%
df['transmission'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='transmission'>

# %%
sns.barplot(x=df['transmission'],y=df['selling_price'])
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='selling_price'>

# %%
df['owner'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='owner'>

# %%
sns.barplot(x=df['owner'],y=df['selling_price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x='mileage', y='selling_price', data=df)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='selling_price'>

# %%
sns.scatterplot(x='max_power', y='selling_price', data=df)
# Out:
# <AxesSubplot:xlabel='max_power', ylabel='selling_price'>

# %%
sns.scatterplot(x='engine', y='selling_price', data=df)
# Out:
# <AxesSubplot:xlabel='engine', ylabel='selling_price'>

# %%
df['seats'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='seats'>

# %%
sns.barplot(x=df['owner'],y=df['selling_price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only= True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Feature Correlation Matrix')
plt.show()

# %%
df.reset_index(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6717 entries, 0 to 6716
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          6717 non-null   int64
#  1   year           6717 non-null   int64
#  2   selling_price  6717 non-null   int64
#  3   km_driven      6717 non-null   int64
#  4   fuel           6717 non-null   object
#  5   seller_type    6717 non-null   object
#  6   transmission   6717 non-null   object
#  7   owner          6717 non-null   object
#  8   mileage        6717 non-null   float32
#  9   engine         6717 non-null   int32
#  10  max_power      6717 non-null   float32
#  11  seats          6717 non-null   float64
#  12  brand_name     6717 non-null   object
# dtypes: float32(2), float64(1), int32(1), int64(4), object(5)
# memory usage: 603.6+ KB

# %%
df.drop(columns=['index'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df.drop(columns=['index'], inplace=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6717 entries, 0 to 6716
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           6717 non-null   int64
#  1   selling_price  6717 non-null   int64
#  2   km_driven      6717 non-null   int64
#  3   fuel           6717 non-null   object
#  4   seller_type    6717 non-null   object
#  5   transmission   6717 non-null   object
#  6   owner          6717 non-null   object
#  7   mileage        6717 non-null   float32
#  8   engine         6717 non-null   int32
#  9   max_power      6717 non-null   float32
#  10  seats          6717 non-null   float64
#  11  brand_name     6717 non-null   object
# dtypes: float32(2), float64(1), int32(1), int64(3), object(5)
# memory usage: 551.1+ KB

# %%
# Model building

# %%
df.head(10)
# Out:
#    year  selling_price  km_driven    fuel seller_type transmission  \
# 0  2014         450000     145500  Diesel  Individual       Manual
# 1  2014         370000     120000  Diesel  Individual       Manual
# 2  2006         158000     140000  Petrol  Individual       Manual
# 3  2010         225000     127000  Diesel  Individual       Manual
# 4  2007         130000     120000  Petrol  Individual       Manual
# 5  2017         440000      45000  Petrol  Individual       Manual
# 6  2007          96000     175000     LPG  Individual       Manual
# 7  2001          45000       5000  Petrol  Individual       Manual
# 8  2011         350000      90000  Diesel  Individual       Manual
# 9  2013         200000     169000  Diesel  Individual       Manual
#
#           owner    mileage  engine   max_power  seats brand_name
# 0   First Owner  23.400000    1248   74.000000    5.0     Maruti
# 1  Second Owner  21.139999    1498  103.519997    5.0      Skoda
# 2   Third Owner  17.700001    1497   78.000000    5.0      Honda
# 3   First Owner  23.000000    1396   90.000000    5.0    Hyundai
# 4   First Owner  16.100000    1298   88.199997    5.0     Maruti
# 5   First Owner  20.139999    1197   81.860001    5.0    Hyundai
# 6   First Owner  17.299999    1061   57.500000    5.0     Maruti
# 7  Second Owner  16.100000     796   37.000000    4.0     Maruti
# 8   First Owner  23.590000    1364   67.099998    5.0     Toyota
# 9   First Owner  20.000000    1399   68.099998    5.0       Ford

# %%
#Converting this new clean dataframe to csv file to use in streamlit app
df.to_csv('new car.csv')

# %%
df.shape
# Out:
# (6717, 12)

# %%
X = df.drop(columns=['selling_price'])
y = df['selling_price']

# %%
X
# Out:
#       year  km_driven    fuel seller_type transmission                 owner  \
# 0     2014     145500  Diesel  Individual       Manual           First Owner
# 1     2014     120000  Diesel  Individual       Manual          Second Owner
# 2     2006     140000  Petrol  Individual       Manual           Third Owner
# 3     2010     127000  Diesel  Individual       Manual           First Owner
# 4     2007     120000  Petrol  Individual       Manual           First Owner
# ...    ...        ...     ...         ...          ...                   ...
# 6712  2013      50000  Petrol  Individual       Manual          Second Owner
# 6713  2014      80000  Diesel  Individual       Manual          Second Owner
# 6714  2013     110000  Petrol  Individual       Manual           First Owner
# 6715  2007     119000  Diesel  Individual       Manual  Fourth & Above Owner
# 6716  2009     120000  Diesel  Individual       Manual           First Owner
#
#         mileage  engine   max_power  seats brand_name
# 0     23.400000    1248   74.000000    5.0     Maruti
# 1     21.139999    1498  103.519997    5.0      Skoda
# 2     17.700001    1497   78.000000    5.0      Honda
# 3     23.000000    1396   90.000000    5.0    Hyundai
# 4     16.100000    1298   88.199997    5.0     Maruti
# ...         ...     ...         ...    ...        ...
# 6712  18.900000     998   67.099998    5.0     Maruti
# 6713  22.540001    1396   88.730003    5.0    Hyundai
# 6714  18.500000    1197   82.849998    5.0    Hyundai
# 6715  16.799999    1493  110.000000    5.0    Hyundai
# 6716  19.299999    1248   73.900002    5.0     Maruti
#
# [6717 rows x 11 columns]

# %%
y
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 6712    260000
# 6713    475000
# 6714    320000
# 6715    135000
# 6716    382000
# Name: selling_price, Length: 6717, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.20)

# %%
X_train
# Out:
#       year  km_driven    fuel seller_type transmission         owner  \
# 569   2017      40000  Petrol  Individual       Manual   First Owner
# 2351  2016      17000  Petrol  Individual    Automatic   First Owner
# 868   2011      90400  Diesel  Individual       Manual   First Owner
# 1481  2016      97000  Diesel  Individual    Automatic   First Owner
# 4626  2012      70000  Diesel  Individual       Manual   First Owner
# ...    ...        ...     ...         ...          ...           ...
# 4322  2015     120000  Diesel  Individual       Manual   First Owner
# 5504  2017      25000  Petrol  Individual       Manual  Second Owner
# 2778  2014      10000  Petrol  Individual       Manual   First Owner
# 1738  2018      20000  Diesel      Dealer    Automatic   First Owner
# 3878  2017      35000  Petrol  Individual       Manual   First Owner
#
#         mileage  engine   max_power  seats  brand_name
# 569   16.799999     796   34.200001    8.0      Maruti
# 2351  23.100000     998   67.040001    5.0      Maruti
# 868   20.000000    1399   68.000000    5.0        Ford
# 1481  16.959999    1968  138.029999    5.0  Volkswagen
# 4626  22.320000    1582  126.320000    5.0     Hyundai
# ...         ...     ...         ...    ...         ...
# 4322  25.799999    1498   98.599998    5.0       Honda
# 5504  17.500000    1199   88.699997    5.0       Honda
# 2778  21.100000     814   55.200001    5.0     Hyundai
# 1738  11.360000    2755  171.500000    8.0      Toyota
# 3878  17.400000    1497  117.599998    5.0       Honda
#
# [5373 rows x 11 columns]

# %%
import pickle
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder()
ohe.fit(X[['fuel','seller_type','transmission','owner','brand_name']])
# Out:
# OneHotEncoder()

# %%
# Random Forest Regressor
step1 = ColumnTransformer(
    transformers=[
        ('ohe', OneHotEncoder(categories=ohe.categories_), ['fuel', 'seller_type', 'transmission', 'owner', 'brand_name'])
    ],
    remainder='passthrough'
)
step2 = RandomForestRegressor()
pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])
pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)
print('R2 score',r2_score(y_test,y_pred))
# Out:
# R2 score 0.9314937510292834

# %%
pickle.dump(pipe, open('pipeline.pkl', 'wb'))
